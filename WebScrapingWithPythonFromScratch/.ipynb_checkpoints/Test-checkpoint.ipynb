# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://www.programmableweb.com/category/tools/api"

cnt_apis = 0
apis_dict = {}

while True:
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data, "html.parser")
    apis_even = soup.find_all("tr", {"class": "even"})
    apis_odd = soup.find_all("tr", {"class": "odd"})
    
    for api in apis_even:
        cnt_apis += 1
        title = api.find("td", {"class": "views-field-title"}).text[1:]
        link = "https://www.programmableweb.com" + api.find("td", {"class": "views-field-title"}).find("a").get("href")
        category = api.find("td", {"class": "views-field-field-article-primary-category"}).text[1:]
        description = api.find("td", {"class": "views-field-field-api-description"}).text[1:]
        apis_dict[cnt_apis] = [title, link, category, description]
        
    for api in apis_odd:
        cnt_apis += 1
        title = api.find("td", {"class": "views-field-title"}).text[1:]
        link = "https://www.programmableweb.com" + api.find("td", {"class": "views-field-title"}).find("a").get("href")
        category = api.find("td", {"class": "views-field-field-article-primary-category"}).text[1:]
        description = api.find("td", {"class": "views-field-field-api-description"}).text[1:]
        apis_dict[cnt_apis] = [title, link, category, description]
        
    url_tag = soup.find("a", {"id": "pager_id_apis_all"})
    if url_tag != None:
        url = "https://www.programmableweb.com" + url_tag.get("href")
    else:
        break
    
print("Total apis:", cnt_apis)

# %%
apis_dict
# Out:
# {1: ['K-meta Keyword Research',
#   'https://www.programmableweb.com/api/k-meta-keyword-research',
#   'Keywords',
#   'Domain research, Actual Fresh Keywords metrics: accurate Search Volume, Cost per Click (CPC), Competition, Historical metrics API. Simple integration method, Accurate data, Displays results in the...'],
#  2: ['Nmap',
#   'https://www.programmableweb.com/api/nmap',
#   'Security',
#   'This method is used to create Nmap scan.'],
#  3: ['Fun Generators Barcode ',
#   'https://www.programmableweb.com/api/fun-generators-barcode',
#   'eCommerce',
#   'Generate barcodes or read barcode images and decode them to barcode numbers. Our barcode API supports most of the major barcode formats.'],
#  4: ['QA Touch',
#   'https://www.programmableweb.com/api/qa-touch',
#   'Software-as-a-Service',
#   'Seamless instant synchronization of your automation test results\nCreate, view and update test modules in QA Touch such as Requirements, Test Cases, Test Runs,\nIssues, Releases and Projects'],
#  5: ['Craft CMS',
#   'https://www.programmableweb.com/api/craft-cms',
#   'Content',
#   'Craft Pro provides an autogenerated GraphQL API for content, to pull your into separate applications, such as single-page apps or static site generators. Craft is a flexible, user-friendly CMS for...'],
#  6: ['Thomson Reuters ONESOURCE Calendar',
#   'https://www.programmableweb.com/api/thomson-reuters-onesource-calendar',
#   'Taxes',
#   'These ONESOURCE APIs use a REST architecture that provides communication via the Thomson Reuters API gateway and allows you to directly access the Thomson Reuters Calendar content library resources...'],
#  7: ['PeopleStrong ',
#   'https://www.programmableweb.com/api/peoplestrong',
#   'Human Resources',
#   'The PeopleStrong API enables you with the ability to; get a list of all employees, the current leave balance of an employee, submit leave requests and more. This includes services for; Employee...'],
#  8: ['OnCrawl ',
#   'https://www.programmableweb.com/api/oncrawl',
#   'SEO',
#   'The OnCrawl REST API provides a way to access OnCrawl data and manage projects. Access to this API requires that you have an account, active subscription and API access Token. OnCrawl is a...'],
#  9: ['eBay Buy Deal',
#   'https://www.programmableweb.com/api/ebay-buy-deal',
#   'Marketplace',
#   'This eBay Deal API provides developers with the ability to search for and retrieve details about eBay deals and events. It allows you to retrieve a paginated set of deal items, return a paginated...'],
#  10: ['API Spot Currency Converter',
#   'https://www.programmableweb.com/api/api-spot-currency-converter',
#   'Currency',
#   'Currency Conversion API'],
#  11: ['API Spot Domain Toolkit',
#   'https://www.programmableweb.com/api/api-spot-domain-toolkit',
#   'Tools',
#   'Domain Names Toolkit API. WHOIS, Domain Check, Reverse WHOIS and IP Lookup'],
#  12: ['Backblaze S3 Compatible ',
#   'https://www.programmableweb.com/api/backblaze-s3-compatible',
#   'Storage',
#   'The Backblaze S3 Compatible API allows existing S3 integrations and SDKs to easily integrate with Backblaze B2 Cloud Storage with supported calls to; Abort Multipart Upload, Complete, Multipart...'],
#  13: ['Screenshot-Capture',
#   'https://www.programmableweb.com/api/screenshot-capture',
#   'Screenshots',
#   'Screenshot Capture API is a simple but powerful screenshot API that anyone can easily use to create pixel-perfect website screenshots. It always uses a recent version of Chrome to ensure that all...'],
#  14: ['ClickHelp',
#   'https://www.programmableweb.com/api/clickhelp',
#   'Tools',
#   'ClickHelp is an online tool for creating technical documentation. Every ClickHelp portal provides a REST API for users to automate tasks and integrate documentation workflow into existing business...'],
#  15: ['Fun Generators Lottery Number generation',
#   'https://www.programmableweb.com/api/fun-generators-lottery-number-generation',
#   'Entertainment',
#   'Generate lottery numbers for over 300+ lottery games around the world. Super easy REST based API.'],
#  16: ['Fun Generators UUID Generation and Parsing',
#   'https://www.programmableweb.com/api/fun-generators-uuid-generation-and-parsing',
#   'Algorithms',
#   'Generate random UUID. Easy to use REST API with complete UUID features support. RFC 4122 based UUIDs as well as non standard version 6 uuid are supported. UUID string parsing is also available to...'],
#  17: ['MX Platform',
#   'https://www.programmableweb.com/api/mx-platform',
#   'Financial',
#   'The MX API is designed to aggregate and enhance financial data with the ability to interact and connect to your applications or website to tens of thousands of financial institutions. This MX API is...'],
#  18: ['Thomson Reuters ONESOURCE',
#   'https://www.programmableweb.com/api/thomson-reuters-onesource',
#   'Taxes',
#   'These ONESOURCE APIs use a REST architecture that provides communication via the Thomson Reuters API gateway and allows you to directly access the Thomson Reuters DataFlow content library resources...'],
#  19: ['IntelOwl',
#   'https://www.programmableweb.com/api/intelowl',
#   'Security',
#   'The IntelOwl API provides a way to integrate applications and get data from multiple sources with a single API request. IntelOwl builds solutions to help communities with the generation of threat...'],
#  20: ['Datashake ',
#   'https://www.programmableweb.com/api/datashake',
#   'Data',
#   'The Datashake API provides a way to retrieve information for a given review profile, return the actual reviews from the scrape, retrieve a list of all your review profile jobs and more. This API...'],
#  21: ['eBay Sell Feed ',
#   'https://www.programmableweb.com/api/ebay-sell-feed',
#   'Marketplace',
#   'This eBay Feed API allows sellers to upload input files, download reports and files with status, the ability to filter reports, retrieve customer service metrics task details and more. It lets...'],
#  22: ['Rosetta ',
#   'https://www.programmableweb.com/api/rosetta',
#   'Blockchain',
#   'This Rosetta Node API is a Specification for blockchain data format and interacting with a blockchain node. It provides a configuration for an automated deployment of the implementation using a...'],
#  23: ['API Spot Email Filter',
#   'https://www.programmableweb.com/api/api-spot-email-filter',
#   'Tools',
#   'Email Validation API'],
#  24: ['Workadu',
#   'https://www.programmableweb.com/api/workadu',
#   'Business',
#   'The Workadu’s API is a RESTful service that is designed to; Create a new Service, Delete a Service, Create a new Price List, Get Specific Service and more. It provides a way to update and delete...'],
#  25: ['CopperEgg Cloud',
#   'https://www.programmableweb.com/api/copperegg-cloud',
#   'Monitoring',
#   'Copperegg builds services to visualize cloud infrastructure performance.']}
